# %%
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import seaborn as sns
from teeplot import teeplot as tp

# %%
nbm.print_metadata()
# Out:
# context: ci
# hostname: fv-az527-491
# interpreter: 3.8.10 (default, Nov 22 2023, 10:22:35)  [GCC 9.4.0]
# nbcellexec: null
# nbname: example
# nbpath: /home/runner/work/phylogeny-informed-evaluation/phylogeny-informed-evaluation/notebooks/example/example.ipynb
# revision: null
# session: 6511e344-bd4f-4392-bef8-22cd2553d6fe
# timestamp: 2024-06-30T00:22:26Z00:00
#
#
# IPython==8.12.3
# keyname==0.6.0
# yaml==5.3.1
# matplotlib==3.7.5
# nbmetalog==0.2.6
# seaborn==0.13.2
# teeplot==1.0.1
# re==2.2.1
# comm==0.2.2
# logging==0.5.1.2
# psutil==6.0.0
# zmq==26.0.3
# json==2.0.9
# ipykernel==6.29.4

# %%
nbm.print_dataframe_synopsis(sns.load_dataset('fmri'))
# Out:
# digest: 8ce0b36ad848674ec5ee08eeed687a1cecc596874929efe703097585b57c8065
# manifest:
#   event: '     2#     ex., stim'
#   region: '    2#     ex., parietal'
#   signal: '    1064#  ex., -0.017551581538'
#   subject: '   14#    ex., s13'
#   timepoint: ' 19#    ex., 18'
# num cols: 5
# num cols all na: 0
# num cols any na: 0
# num na: 0
# num rows: 1064
# num rows all na: 0
# num rows any na: 0
# size: 208K

# %%
tp.tee(
    sns.lineplot,
    x='timepoint',
    y='signal',
    hue='region',
    style='event',
    data=sns.load_dataset('fmri'),
    teeplot_outattrs={
        **{
            'custom' : 'attr',
        },
        **nbm.collate_outattr_metadata(),
    },
)
plt.show()
# Out:
# teeplots/custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.pdf
# teeplots/custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.png
