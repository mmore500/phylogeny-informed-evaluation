# %%
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import seaborn as sns
from teeplot import teeplot as tp

# %%
nbm.print_metadata()
# Out:
# context: ci
# hostname: fv-az1106-410
# interpreter: 3.8.10 (default, May 26 2023, 14:05:08)  [GCC 9.4.0]
# nbcellexec: null
# nbname: example
# nbpath: /home/runner/work/phylogeny-informed-evaluation/phylogeny-informed-evaluation/notebooks/example/example.ipynb
# revision: null
# session: 17d2120c-ddbb-4529-bf73-df9742e9662f
# timestamp: 2023-10-01T00:26:29Z00:00
#
#
# IPython==8.12.3
# keyname==0.5.3
# yaml==5.3.1
# matplotlib==3.7.3
# nbmetalog==0.2.6
# seaborn==0.13.0
# teeplot==0.5.0
# re==2.2.1
# comm==0.1.4
# logging==0.5.1.2
# psutil==5.9.5
# zmq==25.1.1
# json==2.0.9
# ipykernel==6.25.2

# %%
nbm.print_dataframe_synopsis(sns.load_dataset('fmri'))
# Out:
# digest: 8ce0b36ad848674ec5ee08eeed687a1cecc596874929efe703097585b57c8065
# manifest:
#   event: '     2#     ex., stim'
#   region: '    2#     ex., parietal'
#   signal: '    1064#  ex., -0.017551581538'
#   subject: '   14#    ex., s13'
#   timepoint: ' 19#    ex., 18'
# num cols: 5
# num cols all na: 0
# num cols any na: 0
# num na: 0
# num rows: 1064
# num rows all na: 0
# num rows any na: 0
# size: 208K

# %%
tp.tee(
    sns.lineplot,
    x='timepoint',
    y='signal',
    hue='region',
    style='event',
    data=sns.load_dataset('fmri'),
    teeplot_outattrs={
        **{
            'custom' : 'attr',
        },
        **nbm.collate_outattr_metadata(),
    },
)
plt.show()
# Out:
# teeplots/./custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.pdf
# teeplots/./custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.png
